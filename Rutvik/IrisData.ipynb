# %%
import numpy as np
import pandas as pd
import sklearn 
import matplotlib.pyplot as plt
from sklearn import datasets
import seaborn as sns

# %%
iris = pd.read_csv(r"C:\Users\Rutvik\Downloads\Data Science\DS_LAB_Internal -  Question and Datasets - 2023-May\Iris.csv")
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.Species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
iris.Species = iris.Species.map({'Iris-setosa': 0, 'Iris-versicolor':1,'Iris-virginica' :2})
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
iris.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris_target = iris.Species
iris.drop(['Id','Species'],axis=1,inplace=True)

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
sns.scatterplot(x=iris['PetalLengthCm'],y=iris['PetalWidthCm'],hue=iris_target,s=50)
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.pairplot(iris_data)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
x_train,x_test,y_train,y_test = train_test_split(iris_data[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']],iris_target,test_size=0.2,random_state=4)

# %%
classifier = KNeighborsClassifier(n_neighbors=5)
classifier.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = classifier.predict(x_test)

# %%
accuracy = accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.9666666666666667

# %%
cm = confusion_matrix(y_test,y_pred)

# %%
sns.heatmap(cm,annot=True)
# Out:
# <Axes: >
