# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns

# %%
sup = pd.read_csv(r"C:\Users\DELL\Documents\DS_LAB_Internal -  Question and Datasets - 2023-May\50_Startups.csv")

# %%
sup.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
sup['State'].unique()
# Out:
# array(['New York', 'California', 'Florida'], dtype=object)

# %%
sup['State']=sup['State'].map({'New York':1, 'California':2, 'Florida':3})

# %%
sup.head()
# Out:
#    R&D Spend  Administration  Marketing Spend  State     Profit
# 0  165349.20       136897.80        471784.10      1  192261.83
# 1  162597.70       151377.59        443898.53      2  191792.06
# 2  153441.51       101145.55        407934.54      3  191050.39
# 3  144372.41       118671.85        383199.62      1  182901.99
# 4  142107.34        91391.77        366168.42      3  166187.94

# %%
sup.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
y=sup['Profit']

# %%
y
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %%
x=sup.drop('Profit',axis= 'columns')

# %%
x.head()
# Out:
#    R&D Spend  Administration  Marketing Spend  State
# 0  165349.20       136897.80        471784.10      1
# 1  162597.70       151377.59        443898.53      2
# 2  153441.51       101145.55        407934.54      3
# 3  144372.41       118671.85        383199.62      1
# 4  142107.34        91391.77        366168.42      3

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=54321)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((35, 4), (15, 4), (35,), (15,))

# %%
from sklearn.linear_model import LinearRegression
mlr = LinearRegression()

# %%
mlr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = mlr.predict(x_test)

# %%
y_pred
# Out:
# array([171642.21007501, 153507.1622761 ,  48220.9532555 ,  63625.39487609,
#         85509.90727748, 143599.52881975, 181642.03077074, 100120.79463083,
#         78368.87161918,  91037.28752462,  50709.25001541, 153649.40533058,
#        102871.44139633, 111048.74639914, 170990.99771644])

# %%
plt.scatter(y_pred,y_pred-y_test)

# %%
sns.pairplot(sup)
